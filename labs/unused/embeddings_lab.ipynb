# %% [markdown]
# # Lab 4 – Semantic Search and Embedding Space
#
# <a href="https://colab.research.google.com/github/tulane-intro-ai-engineering/main/blob/main/labs/embeddings_lab.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>
#
# In this lab, you’ll investigate how **embeddings** represent meaning geometrically and how **semantic similarity** differs from simple keyword matching.
#
# You’ll:
# - Write your own cosine similarity function.
# - Build a minimal semantic search pipeline.
# - Compare its results with a basic keyword search.
# - Reflect on what you observe.
#
# This lab models **AI engineering as scientific investigation**: change a parameter, measure an outcome, and test your hypothesis.

# %% [markdown]
# ## 🎯 Learning Goals
#
# By the end of this lab, you should be able to:
# 1. Compute cosine similarity between vectors you generate.
# 2. Generate embeddings using the OpenAI API.
# 3. Implement a simple semantic search algorithm.
# 4. Compare keyword and semantic search behavior.
# 5. Interpret cosine similarity as a measure of meaning closeness.

# %%
# @title 🔧 Lab 4 Setup (run this first)
# !git clone --depth 1 -q https://github.com/tulane-intro-ai-engineering/main.git
import sys; sys.path.append('/content/main')
from course_utils import lab4_setup, lab4_generate_visualization, lab4_build_search_demo, simple_keyword_search
import numpy as np
lab4_setup()
print("✅ Environment ready!")
# Out:
# 🔧 Setting up your environment...
#   → Installing core packages...
# installing mermaid-python
#   → Installing additional packages: scikit-learn
#   → Setting random seed for reproducible results...
#   → Checking API key...
# 🔑 Enter your OpenAI API key.
#    (It will only be stored in this Colab runtime - it's safe!)
#    Get your key from: https://platform.openai.com/api-keys
# OpenAI API key: ··········
# ✅ API key set.
#   → Adding course files to path...
# ✅ Setup complete!
# ✅ lab4_setup complete — ready.
# ✅ Environment ready!

# %% [markdown]
# ## 🧠 Pre-Lab Questions
#
# Answer briefly (1–2 sentences each):
#
# 1. What makes two sentences *similar in meaning* even if they use different words?
# 2. When might keyword search fail compared to semantic search?
# 3. What does it mean for two embeddings to be “close” in vector space?

# %% [markdown]
# ## 🔬 Scientific Process
#
# **Question:**
# How does changing the similarity measure (keyword vs. semantic embeddings) affect retrieval quality?
#
# **Hypothesis:**
# I expect semantic search to find relevant results even when no words overlap, while keyword search will only match literal terms.
#
# **Experiment Plan:**
# - Implement cosine similarity.
# - Use embeddings to build a mini semantic search function.
# - Compare retrieval results.
#
# **Measurement:**
# - *Qualitative:* number of relevant results in top 2–3 hits.
# - *Quantitative:* cosine similarity values.
#
# **Expected Conclusion:**
# Semantic search yields higher relevance than keyword search, even when no shared words exist.

# %% [markdown]
# ## Part 1 – Cosine Similarity and Embeddings
#
# We'll give you the `get_embedding` and `cosine_similarity` functions from lecture.

# %%
from openai import OpenAI
import numpy as np
import matplotlib.pyplot as plt

client = OpenAI()
# https://platform.openai.com/docs/models/text-embedding-3-small
EMBEDDING_MODEL = "text-embedding-3-small"

def get_embedding(text: str) -> np.ndarray:
    """Return a 1D numpy array embedding for `text`."""
    # IMPORTANT: this is the key API call we'll use all week
    emb = client.embeddings.create(input=text, model=EMBEDDING_MODEL).data[0].embedding
    return np.array(emb, dtype=np.float32)

def cosine_similarity(a: np.ndarray, b: np.ndarray) -> float:
    """Cosine similarity in [-1, 1]. 1 = same direction."""
    return float(np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)))

# quick test.
v1, v2 = np.array([1, 2, 3]), np.array([2, 4, 6])
print("Expected ≈ 1.0:", cosine_similarity(v1, v2))
# Out:
# Expected ≈ 1.0: 1.0

# %% [markdown]
# ## Part 2 – Generate and Compare Embeddings
#
# Use the OpenAI API to get embeddings for short texts.
# Then compute cosine similarities using your own function.

# %%
# @title 🧠 Generate Embeddings and Compare


texts = ["Tulane University", "New Orleans", "banana"]
embeddings = [get_embedding(t) for t in texts]

pairs = [("Tulane University", "New Orleans"), ("Tulane University", "banana")]
# TODO: Use your cosine_similarity() here
for i, (a, b) in enumerate(pairs):
    print(f"{a} vs {b} → similarity =", "YOUR_CODE_HERE")
# Out:
# Tulane University vs New Orleans → similarity = 0.5217536687850952
# Tulane University vs banana → similarity = 0.11471271514892578

# %% [markdown]
# ## Part 3 – Implement a Mini Semantic Search
#
# Now, let's build a simple **semantic search** system.
# Use embeddings and cosine similarity to find which documents are most related to a query.

# %%
# @title 🔍 TODO: Implement Semantic Search

docs = [
    "Tulane University is located in New Orleans.",
    "Jazz music was born in New Orleans.",
    "Crawfish season peaks in early spring.",
    "AI models learn from data patterns, not logic rules."
]

def my_semantic_search(query, docs, doc_embs, k=2):
    """Return the top k most similar docs using embeddings and cosine similarity.
    query...string of the query
    doc_embs...list of 1D numpy arrays of document embeddings
    """
    # TODO:
    # 1. Compute embedding for query
    # 2. Use cosine_similarity for each pair
    # 3. Sort results and return top 2 docs
    raise NotImplementedError("Implement semantic search pipeline.")

doc_embs = [get_embedding(d) for d in docs]
query = "music in Louisiana"
print(my_semantic_search(query, docs, doc_embs, 2))

# %% [markdown]
# ## Part 4 – Compare Keyword vs Semantic Search
#
# Now test both methods and note which retrieves more meaningful results.

# %%
# @title Compare Search Methods

query = "music in Louisiana"
kw = simple_keyword_search(query, docs)
sem = my_semantic_search(query, docs, doc_embs, k=3)

print("🔹 Keyword:", kw)
print("🔸 Semantic:", sem)

# %% [markdown]
# ### 🧩 Record Your Observations
#
# | Query | Keyword Match | Semantic Match | Which is better? |
# |-------|----------------|----------------|------------------|
# | music in Louisiana | ... | ... | ... |
# | university in New Orleans | ... | ... | ... |
# | seafood | ... | ... | ... |
# | New Orleans seafood | ... | ... | ... |

# %% [markdown]
# ## Part 5 – Interactive Exploration
#
# Try your own examples using this Gradio app.

# %%
# @title 🎛️ Interactive Search App
demo = lab4_build_search_demo(search_fn=my_semantic_search)
demo.launch(debug=True)

# %% [markdown]
# ## 📈 Results & Conclusion
#
# - Which system was more accurate for semantic meaning?
# - Was your hypothesis supported?
# - Did cosine similarity values match your intuition?

# %% [markdown]
# ## 💭 Post-Lab Reflection
#
# 1. Describe one example where the model’s results surprised you.
# 2. When might semantic search fail?
# 3. What is one new question you have about embeddings or similarity?

# %% [markdown]
# ---
#
# ## 🧠 AI Usage Log
#
# > Use this section to document any generative AI assistance (e.g., ChatGPT, Claude, Copilot) you used while completing this lab or assignment.
# > Be specific — transparency and reflection matter more than the amount of AI use.
#
#
# | Tool Used | Purpose | Prompt / Context | Verification & Edits |
# |------------|----------|------------------|----------------------|
# | (e.g., ChatGPT (GPT-5)) | (e.g., debugging, code explanation, idea generation) | (e.g., "Why does my cosine similarity return NaN?") | (e.g., ran tests on sample input, compared with lecture code) |
# | (Add rows as needed) | | | |
#
# **Summary (2–3 sentences):**
# Briefly describe what you learned or how AI helped you think through the problem.
# Example: *AI helped me notice an off-by-one error in my indexing. I double-checked by printing intermediate results and confirmed the fix.*
#
# ---

# %%
# @title ✅ Run Lab 4 Checks

import numpy as np

try:
    a,b = np.array([1,0]), np.array([0,1])
    sim = cosine_similarity(a,b)
    assert abs(sim) < 1e-6, "cosine_similarity should give 0 for orthogonal vectors"
    print("✅ cosine_similarity works correctly.")
except Exception as e:
    print("⚠️ cosine_similarity check failed:", e)

try:
    assert callable(my_semantic_search), "my_semantic_search not defined"
    print("✅ my_semantic_search structure OK.")
except Exception as e:
    print("⚠️ semantic search check failed:", e)

# %% [markdown]
# <details>
# <summary>📘 Instructor Notes</summary>
#
# **Timing:**
# - 10 min review of previous lab (pipelines & dspy)
# - 10 min intro to embeddings
# - 40 min implementation (Parts 1–4)
# - 10 min demo and discussion
# - 5 min reflection
#
# **Extensions:**
# - Try embeddings for phrases in other languages.
# - Visualize clusters using PCA or t-SNE.
#
# **Quiz Alignment:**
# - Reinforces cosine similarity & semantic search concepts.
# </details>
